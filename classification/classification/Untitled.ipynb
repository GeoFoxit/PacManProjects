# %%
import pickle

# %%
with open('pacmandata/contest_training.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'actions': ['West',
#   'West',
#   'West',
#   'North',
#   'North',
#   'West',
#   'West',
#   'West',
#   'North',
#   'North',
#   'West',
#   'West',
#   'North',
#   'North',
#   'North',
#   'North',
#   'East',
#   'East',
#   'East',
#   'South',
#   'South',
#   'East',
#   'East',
#   'East',
#   'East',
#   'East',
#   'East',
#   'East',
#   'East',
#   'East',
#   'East',
#   'East',
#   'East',
#   'South',
#   'South',
#   'West',
#   'West',
#   'West',
#   'South',
#   'South',
#   'West',
#   'West',
#   'West',
#   'West',
#   'West',
#   'West',
#   'West',
#   'North',
#   'North',
#   'West',
#   'West',
#   'West',
#   'North',
#   'North',
#   'East',
#   'East',
#   'East',
#   'North',
#   'North',
#   'East',
#   'East',
#   'East',
#   'East',
#   'East',
#   'East',
#   'East',
#   'West',
#   'West',
#   'West',
#   'West',
#   'West',
#   'West',
#   'West',
#   'South',
#   'South',
#   'South',
#   'South',
#   'South',
#   'South',
#   'West',
# ...
